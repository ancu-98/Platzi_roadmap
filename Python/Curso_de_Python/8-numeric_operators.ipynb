# %% [markdown]
# # Clase 08: Operaciones Matemáticas en Python
#
# En el mundo de la programación con Python, las operaciones matemáticas básicas como la suma, resta, multiplicación y división son fundamentales.
#
# Sin embargo, Python ofrece operaciones adicionales que expanden nuestras posibilidades.

# %% [markdown]
# ### ¿Cómo realizamos las operaciones matemáticas básicas en Python?
#
# Primero, creamos dos variables: a con valor 10 y b con valor 3. Usamos comentarios para indicar que estamos trabajando con operadores numéricos.
#
# Imprimimos los resultados de las cuatro operaciones básicas:

# %%
a = 10
b = 3
print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)
# Out:
# Suma: 13
# Resta: 7
# Multiplicación: 30
# División: 3.3333333333333335

# %% [markdown]
# ### ¿Qué es el operador módulo y cómo se usa?
#
# El operador módulo (%) obtiene el residuo de una división.
#
# Por ejemplo, 13 % 5 devuelve 3. En Python, se usa así:

# %%
a = 13
b = 5
print("Módulo:", a % b)
# Out:
# Módulo: 3

# %% [markdown]
# ### ¿Qué sucede al dividir por cero en Python?
#
# Dividir por cero genera un error. Para ilustrarlo:

# %%
a = 10
b = 0
try:
    print(a / b)
except ZeroDivisionError:
    print("Error: División por cero")
# Out:
# Error: División por cero

# %% [markdown]
# ### ¿Qué es la división de enteros y cómo se implementa?
#
# La división de enteros (//) devuelve solo la parte entera de una división. Por ejemplo:

# %%
a = 10
b = 3
print("División Entera:", a // b)
# Out:
# División Entera: 3

# %% [markdown]
# ### ¿Cómo se realiza la potenciación en Python?
#
# La potenciación se representa con **. Para elevar 10 al cubo, usamos:

# %%
a = 10
b = 3
print("Potenciación:", a ** b)
# Out:
# Potenciación: 1000

# %% [markdown]
# ### ¿Qué es PEMDAS y cómo afecta nuestras operaciones?
#
# ![image.png](attachment:image.png)
#
# PEMDAS es la regla de prioridad de operaciones: Paréntesis, Exponentes, Multiplicación y División (de izquierda a derecha), Adición y Sustracción (de izquierda a derecha). Veamos un ejemplo:

# %%
operation = (2 + 3) * 4
print(operation)  # Resultado: 20
# Out:
# 20

# %% [markdown]
# ### Código de la clase

# %%
#Operadores numéricos
print('****Numeric operators****')
a = 10
b = 10
print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("Potenciación:", a ** b)
print("División:", a / b)
print("Parte entera de la división:", a // b)
print("Módulo:", a % b)

# Podemos utilizar atajos (Shortcuts) para realizar operaciones básicas
# Sumear el número 2 a la variable a
print('****Shorcuts****')
# Sumarle 2 a la variable a
# a = a + 2
a += 2
print("Suma:", a)
# Restarle 2 a la variable a
# a = a - 2
a -= 2
print("Resta:", a)
# Multiplicarle 2 a la variable a
# a = a * 2
a *= 2
print("Multiplicación:", a)
# Potenciarle 2 a la variable a
# a = a ** 2
a **= 2
print("Potenciación:", a)
# Dividirle 2 a la variable a
# a = a / 2
a /= 2
print("División:", a)
# División entera de 2 a la variable a
# a = a // 2
a //= 2
print("Parte entera de la división:", a)
# Modulo de 2 a la variable a
# a = a % 2
a %= 2
print("Módulo:", a)

# PEMDAS
print('****PEMDAS****')
operation_1  = 2 + 3 * 4
operation_2  = (2 + 3) * 4
print(operation_1)
print(operation_2)
operation_3 = (2+3) * (4**2)/ 8 - 1
print(operation_3)
# Out:
# ****Numeric operators****
# Suma: 20
# Resta: 0
# Multiplicación: 100
# Potenciación: 10000000000
# División: 1.0
# Parte entera de la división: 1
# Módulo: 0
# ****Shorcuts****
# Suma: 12
# Resta: 10
# Multiplicación: 20
# Potenciación: 400
# División: 200.0
# Parte entera de la división: 100.0
# Módulo: 0.0
# ****PEMDAS****
# 14
# 20
# 9.0
