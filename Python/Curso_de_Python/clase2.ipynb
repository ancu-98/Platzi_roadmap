# %% [markdown]
# # Clase 02: Instalación Python y VSCode
#
# Python es uno de los lenguajes más amigables ara iniciar en la programación de hecho si comparamos con otros lenguajes necesitaremos de múltiples líneas de código para escribir el Hola mundo.
#
# En cambio en python solamente necesitaremos una que es el print Hola mundo lo veremos a continuación.
#
# Ahora instalaremos python en tu computadora.
#
# -  Para iniciar instalaremos python en Windows:
# 1. Ve al navegador y escribe: Python, luego asegúrate de que estás entrando a donde dice python.org y daremos clic:
#
# ![image.png](attachment:image.png)
#
# 2. Verás una sección donde dice descargas Download en la página oficial:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 3. Una vez que haya terminado de Descargar vamos a Acceder al instalador en la carpeta de Descargas y damos doble clic.
# Ahí está abriendo:
#
# ![image-4.png](attachment:image-4.png)
#
# Aasegúrate de marcar esta parte que dice add python.exe to PATH, porque es esencial que se haga especialmente en Windows.
# Luego vamos a dar clic en instalar
#
# ![image-5.png](attachment:image-5.png)
#
# 4. Perfecto con esto ya tenemos Python instalado, ahora solo queda comprobar que está en el sistema.
# Cerraremos la ventana de instalación y nos dirigiremos a buscar la terminal o en Windows también lo puedes hacer con el nombre de cmd para habilitar el símbolo de sistema:
#
# ![image-6.png](attachment:image-6.png)
#
# Luego escribe python presiona enter y tendrás acceso al intérprete de python
# que también te mencionará la versión que estás utilizando y que está instalada en tu computadora, en este caso las 3.12.4
#
#
# - Ahora instalaremos python en Mac.
# 1. Ve a tu navegador y escribe python, recuerda asegurarte que estés ingresando a python.org.
#
# 2. Luego Busca la sección de descargas y busca el sistema operativo de mac sistema operativo de Mac os
#
# Luego descargamos con este botón esperamos a que se descargue el instalador
#
# 3. Lo abrimos en la carpeta de descargas y lo que tenemos es una pantalla donde lo único que hay que hacer es dar clic en continuar
#
# Confirmamos que queremos instalar
#
# Aceptamos los términos y condiciones, luego le ponemos la contraseña
#
# Y ya está instalado python.
#
# 4. Nuevamente vamos a asegurar que python está instalado en el sistema vamos a ir al buscador y escribimos: terminal, luego presionamos enter.
#
# Ejecutamos la línea: python, y nuevamente tenemos acceso a lo que es el intérprete con la versión que tenemos instalada en Mac.
#
# Ahora que tienes python instalado en tu computadora vamos a correr python empezando con el Hola mundo.
#
# Luego de que abriste el intérprete de python escribe en la terminal print seguido de paréntesis y en medio pon "Hola mundo", al final presiona enter
#
# Y lo que vemos, es que la consola ha impreso el mensaje que nosotros tenemos dentro de la función print().
#
# Lo que hace el intérprete es recibir la instrucción que le estamos dando que es el print("Hola mundo"), para que cuando presionemos enter podamos visualizar el resultado de ella.
#
# Python es un **Lenguaje Interpretado** lo que significa que no pasa por un proceso de compilación, por lo que el intérprete recibe la información del print("Hola mundo") y la ejecuta directamente para visualizar el resultado.
#
# ### Instalar y Configurar VSCode para Python
#
# En el mundo profesional es más que seguro que vas a utilizar un editor de código para utilizar Python existen dos que son bastante famosos Visual Studio Code y Py Charm, en este caso instalaremos Visual Studio Code.
#
# - Para istalar VSCode:
# 1. Ve al navegador y escribe Visual Studio Code asegúrate de entrar al enlace que hace referencia a code punto visual studio.com
#
# ![image-16.png](attachment:image-16.png)
#
# En este caso voy a estar haciendo la instalación en Windows pero los pasos son exactamente los mismos para Mac.
#
# 2. vamos a descargar el instalador
#
# ![image-17.png](attachment:image-17.png)
#
# 3. Y una vez que descargue el instalador lo vamos a ejecutar.
# Vamos a aceptar los términos y condiciones
#
# ![image-18.png](attachment:image-18.png)
#
# Damos clic en siguiente
#
# ![image-19.png](attachment:image-19.png)
#
# siguiente
#
# ![image-20.png](attachment:image-20.png)
#
# siguiente
#
# ![image-21.png](attachment:image-21.png)
#
# e instalado
#
# ![image-22.png](attachment:image-22.png)
# ![image-23.png](attachment:image-23.png)
#
#
# ahora que tenemos instalado nos aseguramos que esté presionado esto de ejecutar visual Studio code y presionamos finalizar ahora que tenemos visual Studio vamos a generar nuestro primer código en python para guardar los ejercicios que vamos a estar realizando en el curso vamos a crear una carpeta en este caso al inicio le ponemos carpeta voy a poner curso python para que aquí guardemos los ejercicios luego me dirijo aviso al estudio code y voy a abrir el folder que Acabo de crear estoy en escritorio entro a curso python y selecciono la carpeta
